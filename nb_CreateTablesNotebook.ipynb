# %%
# %sql
create table intellibi_catalog.intellibi_schema.employee
(
    id int,
    name string,
    salary double
);

# %%
# %sql
INSERT INTO intellibi_catalog.intellibi_schema.employee
VALUES
    (1, 'John', 50000.0),
    (2, 'Alice', 65000.0),
    (3, 'Bob', 72000.0);
