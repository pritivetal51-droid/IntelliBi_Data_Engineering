-- %%
CREATE TABLE intellibi_catalog.intellibi_silver.cleansedMonthlySales
(
    sale_id INT,
    product STRING,
    category STRING,
    quantity INT,
    price DOUBLE,
    sale_date DATE,
    region STRING,
    ingest_ts TIMESTAMP
);
