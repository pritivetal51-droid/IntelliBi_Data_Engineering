-- %%
CREATE OR REPLACE TABLE intellibi_catalog.intellibi_bronze.rawMonthlySales
(
    sale_id STRING,
    product STRING,
    category STRING,
    quantity STRING,
    price STRING,
    sale_date STRING,
    region STRING,
    ingest_ts TIMESTAMP
);
